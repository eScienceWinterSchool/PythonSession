# %% [markdown]
# <br>
# <center><img src="https://i.imgur.com/hkb7Bq7.png" width="500"></center>
#
#
# ### Prof. José Manuel Magallanes, PhD
#
# * Associate Professor, Departamento de Ciencias Sociales, Pontificia Universidad Católica del Perú, [jmagallanes@pucp.edu.pe](mailto:jmagallanes@pucp.edu.pe)
#
# * Visiting Associate Professor, Evans School of Public Policy and Governance / Senior Data Science Fellow, eScience Institute, University of Washington, [magajm@uw.edu](mailto:magajm@uw.edu)
# _____
#
# _____

# %% [markdown]
# # Session 1: Introduction to Python - EXERCISES

# %% [markdown]
# ## CASE 1: HDI

# %% [markdown]
# Link from Google:

# %%
link1="https://docs.google.com/spreadsheets/d/e/2PACX-1vSNMpr1Dz3tvMqEAnmGAjaQi19zcsEiLZQn6f5ZM6ap4tzNy6bQUXtctNebCL4OyEN6UODUc0U7B9pf/pub?gid=1506000439&single=true&output=csv"

# %% [markdown]
# Collecting the data with the link from Google:

# %%
# need to call pandas:

import pandas as pd

hdi=pd.read_csv(link1)

# %% [markdown]
# ### -  Cleaning

# %% [markdown]
# Keep only data for data frame

# %% [markdown]
# #### * Check first rows

# %%
# Is the header in the right place:
hdi.head(10)
# Out:
#   Unnamed: 0 Table 1. Human Development Index and its components   \
# 0        NaN                                                NaN
# 1        NaN                                                NaN
# 2        NaN                                                NaN
# 3        NaN                                                NaN
# 4   HDI rank                                            Country
# 5        NaN                                                NaN
# 6        NaN                        VERY HIGH HUMAN DEVELOPMENT
# 7          1                                             Norway
# 8          2                                        Switzerland
# 9          3                                            Ireland
#
#                        Unnamed: 2  Unnamed: 3                Unnamed: 4  \
# 0                             NaN         NaN                       NaN
# 1                             NaN         NaN                      SDG3
# 2                             NaN         NaN                       NaN
# 3  Human development index (HDI)          NaN  Life expectancy at birth
# 4                   (index value)         NaN                   (years)
# 5                         2018.00         NaN                   2018.00
# 6                             NaN         NaN                       NaN
# 7                            0.95         NaN                     82.27
# 8                            0.95         NaN                     83.63
# 9                            0.94         NaN                     82.10
#
#   Unnamed: 5                   Unnamed: 6 Unnamed: 7               Unnamed: 8  \
# 0        NaN                          NaN        NaN                      NaN
# 1        NaN                       SDG4.3        NaN                   SDG4.6
# 2        NaN                          NaN        NaN                      NaN
# 3        NaN  Expected years of schooling        NaN  Mean years of schooling
# 4        NaN                      (years)        NaN                  (years)
# 5        NaN                      2018.00          a                  2018.00
# 6        NaN                          NaN        NaN                      NaN
# 7        NaN                        18.06          b                    12.57
# 8        NaN                        16.21        NaN                    13.38
# 9        NaN                        18.79          b                    12.53
#
#   Unnamed: 9                             Unnamed: 10 Unnamed: 11  \
# 0        NaN                                     NaN         NaN
# 1        NaN                                  SDG8.5         NaN
# 2        NaN                                     NaN         NaN
# 3        NaN  Gross national income (GNI) per capita         NaN
# 4        NaN                            (2011 PPP $)         NaN
# 5          a                                 2018.00         NaN
# 6        NaN                                     NaN         NaN
# 7        NaN                                68058.62         NaN
# 8        NaN                                59374.73         NaN
# 9          c                                55659.68         NaN
#
#                           Unnamed: 12  Unnamed: 13 Unnamed: 14
# 0                                 NaN          NaN         NaN
# 1                                 NaN          NaN         NaN
# 2                                 NaN          NaN         NaN
# 3  GNI per capita rank minus HDI rank          NaN    HDI rank
# 4                                 NaN          NaN         NaN
# 5                             2018.00          NaN     2017.00
# 6                                 NaN          NaN         NaN
# 7                                5.00          NaN        1.00
# 8                                8.00          NaN        2.00
# 9                                9.00          NaN        3.00

# %% [markdown]
# Two problems:
#
# * The headers are in two different rows.
# * The data starts in below zero.
#
# Cleaning the top part:
#
# * Saving the headers:

# %%
# for the first two columns:
hdi.iloc[4,:2].tolist()
# Out:
# ['HDI rank', 'Country']

# %%
# for the rest of columns columns:
hdi.iloc[3,2:].tolist()
# Out:
# ['Human development index (HDI) ',
#  nan,
#  'Life expectancy at birth',
#  nan,
#  'Expected years of schooling',
#  nan,
#  'Mean years of schooling',
#  nan,
#  'Gross national income (GNI) per capita',
#  nan,
#  'GNI per capita rank minus HDI rank',
#  nan,
#  'HDI rank']

# %%
# saving headers:
CurrentHeaders=hdi.iloc[4,:2].tolist()+hdi.iloc[3,2:].tolist()

# you saved this:
CurrentHeaders
# Out:
# ['HDI rank',
#  'Country',
#  'Human development index (HDI) ',
#  nan,
#  'Life expectancy at birth',
#  nan,
#  'Expected years of schooling',
#  nan,
#  'Mean years of schooling',
#  nan,
#  'Gross national income (GNI) per capita',
#  nan,
#  'GNI per capita rank minus HDI rank',
#  nan,
#  'HDI rank']

# %% [markdown]
# * Setting the begining of data:
#
# We need to get rid the top rows that are not part of the data frame:

# %%
# PREVIES: deleting rows, NORWAY should be the first row:
hdi.drop(index=range(0,7)) #7 in range() will not be erased.
# Out:
#     Unnamed: 0 Table 1. Human Development Index and its components   \
# 7            1                                             Norway
# 8            2                                        Switzerland
# 9            3                                            Ireland
# 10           4                                            Germany
# 11           4                             Hong Kong, China (SAR)
# ..         ...                                                ...
# 264        NaN                         Column 2: UNDESA (2019b).
# 265        NaN  Column 3: UNESCO Institute for Statistics (201...
# 266        NaN  Column 4: UNESCO Institute for Statistics (201...
# 267        NaN  Column 5: World Bank (2019a), IMF (2019) and U...
# 268        NaN  Column 6: Calculated based on data in columns ...
#
#     Unnamed: 2  Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 7         0.95         NaN      82.27        NaN      18.06          b
# 8         0.95         NaN      83.63        NaN      16.21        NaN
# 9         0.94         NaN      82.10        NaN      18.79          b
# 10        0.94         NaN      81.18        NaN      17.10        NaN
# 11        0.94         NaN      84.69        NaN      16.51        NaN
# ..         ...         ...        ...        ...        ...        ...
# 264        NaN         NaN        NaN        NaN        NaN        NaN
# 265        NaN         NaN        NaN        NaN        NaN        NaN
# 266        NaN         NaN        NaN        NaN        NaN        NaN
# 267        NaN         NaN        NaN        NaN        NaN        NaN
# 268        NaN         NaN        NaN        NaN        NaN        NaN
#
#     Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12  Unnamed: 13  \
# 7        12.57        NaN    68058.62         NaN        5.00          NaN
# 8        13.38        NaN    59374.73         NaN        8.00          NaN
# 9        12.53          c    55659.68         NaN        9.00          NaN
# 10       14.13        NaN    46945.95         NaN       15.00          NaN
# 11       12.04        NaN    60220.80         NaN        5.00          NaN
# ..         ...        ...         ...         ...         ...          ...
# 264        NaN        NaN         NaN         NaN         NaN          NaN
# 265        NaN        NaN         NaN         NaN         NaN          NaN
# 266        NaN        NaN         NaN         NaN         NaN          NaN
# 267        NaN        NaN         NaN         NaN         NaN          NaN
# 268        NaN        NaN         NaN         NaN         NaN          NaN
#
#     Unnamed: 14
# 7          1.00
# 8          2.00
# 9          3.00
# 10         4.00
# 11         6.00
# ..          ...
# 264         NaN
# 265         NaN
# 266         NaN
# 267         NaN
# 268         NaN
#
# [262 rows x 15 columns]

# %% [markdown]
# Making effective the last code:

# %%
hdi.drop(index=range(0,7),inplace=True)

# %% [markdown]
# As soon as you delete rows, you should reset the indexes:

# %%
hdi.reset_index(drop=True,inplace=True)

# %% [markdown]
# You can rename the columns now:

# %%
# rename columns
hdi.columns=CurrentHeaders

# %% [markdown]
# So far:

# %%
hdi.head()
# Out:
#   HDI rank                 Country Human development index (HDI)   NaN  \
# 0        1                  Norway                           0.95  NaN
# 1        2             Switzerland                           0.95  NaN
# 2        3                 Ireland                           0.94  NaN
# 3        4                 Germany                           0.94  NaN
# 4        4  Hong Kong, China (SAR)                           0.94  NaN
#
#   Life expectancy at birth  NaN Expected years of schooling  NaN  \
# 0                    82.27  NaN                       18.06    b
# 1                    83.63  NaN                       16.21  NaN
# 2                    82.10  NaN                       18.79    b
# 3                    81.18  NaN                       17.10  NaN
# 4                    84.69  NaN                       16.51  NaN
#
#   Mean years of schooling  NaN Gross national income (GNI) per capita  NaN  \
# 0                   12.57  NaN                               68058.62  NaN
# 1                   13.38  NaN                               59374.73  NaN
# 2                   12.53    c                               55659.68  NaN
# 3                   14.13  NaN                               46945.95  NaN
# 4                   12.04  NaN                               60220.80  NaN
#
#   GNI per capita rank minus HDI rank  NaN HDI rank
# 0                               5.00  NaN     1.00
# 1                               8.00  NaN     2.00
# 2                               9.00  NaN     3.00
# 3                              15.00  NaN     4.00
# 4                               5.00  NaN     6.00

# %% [markdown]
# #### * Check last rows

# %%
hdi.tail(65) #change until you see last data row
# Out:
#     HDI rank                                            Country  \
# 197       ..                                            Somalia
# 198       ..                                             Tuvalu
# 199      NaN                                                NaN
# 200      NaN                           Human development groups
# 201      NaN                        Very high human development
# ..       ...                                                ...
# 257      NaN                         Column 2: UNDESA (2019b).
# 258      NaN  Column 3: UNESCO Institute for Statistics (201...
# 259      NaN  Column 4: UNESCO Institute for Statistics (201...
# 260      NaN  Column 5: World Bank (2019a), IMF (2019) and U...
# 261      NaN  Column 6: Calculated based on data in columns ...
#
#     Human development index (HDI)   NaN Life expectancy at birth  NaN  \
# 197                             ..  NaN                    57.07  NaN
# 198                             ..  NaN                       ..  NaN
# 199                            NaN  NaN                      NaN  NaN
# 200                            NaN  NaN                      NaN  NaN
# 201                           0.89  NaN                    79.51  NaN
# ..                             ...  ...                      ...  ...
# 257                            NaN  NaN                      NaN  NaN
# 258                            NaN  NaN                      NaN  NaN
# 259                            NaN  NaN                      NaN  NaN
# 260                            NaN  NaN                      NaN  NaN
# 261                            NaN  NaN                      NaN  NaN
#
#     Expected years of schooling  NaN Mean years of schooling  NaN  \
# 197                          ..  NaN                      ..  NaN
# 198                       12.31  NaN                      ..  NaN
# 199                         NaN  NaN                     NaN  NaN
# 200                         NaN  NaN                     NaN  NaN
# 201                       16.36  NaN                   12.04  NaN
# ..                          ...  ...                     ...  ...
# 257                         NaN  NaN                     NaN  NaN
# 258                         NaN  NaN                     NaN  NaN
# 259                         NaN  NaN                     NaN  NaN
# 260                         NaN  NaN                     NaN  NaN
# 261                         NaN  NaN                     NaN  NaN
#
#     Gross national income (GNI) per capita  NaN  \
# 197                                     ..  NaN
# 198                                5408.95  NaN
# 199                                    NaN  NaN
# 200                                    NaN  NaN
# 201                               40111.57  NaN
# ..                                     ...  ...
# 257                                    NaN  NaN
# 258                                    NaN  NaN
# 259                                    NaN  NaN
# 260                                    NaN  NaN
# 261                                    NaN  NaN
#
#     GNI per capita rank minus HDI rank  NaN HDI rank
# 197                                 ..  NaN       ..
# 198                                 ..  NaN       ..
# 199                                NaN  NaN      NaN
# 200                                NaN  NaN      NaN
# 201                                  —  NaN        —
# ..                                 ...  ...      ...
# 257                                NaN  NaN      NaN
# 258                                NaN  NaN      NaN
# 259                                NaN  NaN      NaN
# 260                                NaN  NaN      NaN
# 261                                NaN  NaN      NaN
#
# [65 rows x 15 columns]

# %% [markdown]
# Based on what is diSplayed, you should keep data up to Tuvalu country:

# %%
# deleting: preview
hdi.drop(index=range(199,262)) # rows starting from 199 will be erased
# Out:
#     HDI rank                 Country Human development index (HDI)   NaN  \
# 0          1                  Norway                           0.95  NaN
# 1          2             Switzerland                           0.95  NaN
# 2          3                 Ireland                           0.94  NaN
# 3          4                 Germany                           0.94  NaN
# 4          4  Hong Kong, China (SAR)                           0.94  NaN
# ..       ...                     ...                            ...  ...
# 194       ..                  Monaco                             ..  NaN
# 195       ..                   Nauru                             ..  NaN
# 196       ..              San Marino                             ..  NaN
# 197       ..                 Somalia                             ..  NaN
# 198       ..                  Tuvalu                             ..  NaN
#
#     Life expectancy at birth  NaN Expected years of schooling  NaN  \
# 0                      82.27  NaN                       18.06    b
# 1                      83.63  NaN                       16.21  NaN
# 2                      82.10  NaN                       18.79    b
# 3                      81.18  NaN                       17.10  NaN
# 4                      84.69  NaN                       16.51  NaN
# ..                       ...  ...                         ...  ...
# 194                       ..  NaN                          ..  NaN
# 195                       ..  NaN                       11.26    e
# 196                       ..  NaN                       15.11  NaN
# 197                    57.07  NaN                          ..  NaN
# 198                       ..  NaN                       12.31  NaN
#
#     Mean years of schooling  NaN Gross national income (GNI) per capita  NaN  \
# 0                     12.57  NaN                               68058.62  NaN
# 1                     13.38  NaN                               59374.73  NaN
# 2                     12.53    c                               55659.68  NaN
# 3                     14.13  NaN                               46945.95  NaN
# 4                     12.04  NaN                               60220.80  NaN
# ..                      ...  ...                                    ...  ...
# 194                      ..  NaN                                     ..  NaN
# 195                      ..  NaN                               17312.59  NaN
# 196                      ..  NaN                                     ..  NaN
# 197                      ..  NaN                                     ..  NaN
# 198                      ..  NaN                                5408.95  NaN
#
#     GNI per capita rank minus HDI rank  NaN HDI rank
# 0                                 5.00  NaN     1.00
# 1                                 8.00  NaN     2.00
# 2                                 9.00  NaN     3.00
# 3                                15.00  NaN     4.00
# 4                                 5.00  NaN     6.00
# ..                                 ...  ...      ...
# 194                                 ..  NaN       ..
# 195                                 ..  NaN       ..
# 196                                 ..  NaN       ..
# 197                                 ..  NaN       ..
# 198                                 ..  NaN       ..
#
# [199 rows x 15 columns]

# %% [markdown]
# Making effective the last code:

# %%
hdi.drop(index=range(199,262),inplace=True) # should I reset indexes?

# %% [markdown]
# So far:

# %%
hdi
# Out:
#     HDI rank                 Country Human development index (HDI)   NaN  \
# 0          1                  Norway                           0.95  NaN
# 1          2             Switzerland                           0.95  NaN
# 2          3                 Ireland                           0.94  NaN
# 3          4                 Germany                           0.94  NaN
# 4          4  Hong Kong, China (SAR)                           0.94  NaN
# ..       ...                     ...                            ...  ...
# 194       ..                  Monaco                             ..  NaN
# 195       ..                   Nauru                             ..  NaN
# 196       ..              San Marino                             ..  NaN
# 197       ..                 Somalia                             ..  NaN
# 198       ..                  Tuvalu                             ..  NaN
#
#     Life expectancy at birth  NaN Expected years of schooling  NaN  \
# 0                      82.27  NaN                       18.06    b
# 1                      83.63  NaN                       16.21  NaN
# 2                      82.10  NaN                       18.79    b
# 3                      81.18  NaN                       17.10  NaN
# 4                      84.69  NaN                       16.51  NaN
# ..                       ...  ...                         ...  ...
# 194                       ..  NaN                          ..  NaN
# 195                       ..  NaN                       11.26    e
# 196                       ..  NaN                       15.11  NaN
# 197                    57.07  NaN                          ..  NaN
# 198                       ..  NaN                       12.31  NaN
#
#     Mean years of schooling  NaN Gross national income (GNI) per capita  NaN  \
# 0                     12.57  NaN                               68058.62  NaN
# 1                     13.38  NaN                               59374.73  NaN
# 2                     12.53    c                               55659.68  NaN
# 3                     14.13  NaN                               46945.95  NaN
# 4                     12.04  NaN                               60220.80  NaN
# ..                      ...  ...                                    ...  ...
# 194                      ..  NaN                                     ..  NaN
# 195                      ..  NaN                               17312.59  NaN
# 196                      ..  NaN                                     ..  NaN
# 197                      ..  NaN                                     ..  NaN
# 198                      ..  NaN                                5408.95  NaN
#
#     GNI per capita rank minus HDI rank  NaN HDI rank
# 0                                 5.00  NaN     1.00
# 1                                 8.00  NaN     2.00
# 2                                 9.00  NaN     3.00
# 3                                15.00  NaN     4.00
# 4                                 5.00  NaN     6.00
# ..                                 ...  ...      ...
# 194                                 ..  NaN       ..
# 195                                 ..  NaN       ..
# 196                                 ..  NaN       ..
# 197                                 ..  NaN       ..
# 198                                 ..  NaN       ..
#
# [199 rows x 15 columns]

# %% [markdown]
# #### * Check the column names

# %% [markdown]
# You have columns with names "missing", you want to avoid those:

# %%
# Get good columns

GoodHeaders=[header for header in CurrentHeaders if str(header) != 'nan']
#
GoodHeaders
# Out:
# ['HDI rank',
#  'Country',
#  'Human development index (HDI) ',
#  'Life expectancy at birth',
#  'Expected years of schooling',
#  'Mean years of schooling',
#  'Gross national income (GNI) per capita',
#  'GNI per capita rank minus HDI rank',
#  'HDI rank']

# %% [markdown]
# The column **HDI rank** appears twice, because it appears twice in the data. Also, you have another rank **GNI per capita rank minus HDI rank'**. Ranks are repetitive because we have the scores. So, you can always get rid of them in this and other similar situations:

# %%
FinalHeaders=[header for header in GoodHeaders if 'rank' not in header]
# then
FinalHeaders
# Out:
# ['Country',
#  'Human development index (HDI) ',
#  'Life expectancy at birth',
#  'Expected years of schooling',
#  'Mean years of schooling',
#  'Gross national income (GNI) per capita']

# %%
# remember loc works with names, not with positions:

hdi.loc[:,FinalHeaders]
# Out:
#                     Country Human development index (HDI)   \
# 0                    Norway                           0.95
# 1               Switzerland                           0.95
# 2                   Ireland                           0.94
# 3                   Germany                           0.94
# 4    Hong Kong, China (SAR)                           0.94
# ..                      ...                            ...
# 194                  Monaco                             ..
# 195                   Nauru                             ..
# 196              San Marino                             ..
# 197                 Somalia                             ..
# 198                  Tuvalu                             ..
#
#     Life expectancy at birth Expected years of schooling  \
# 0                      82.27                       18.06
# 1                      83.63                       16.21
# 2                      82.10                       18.79
# 3                      81.18                       17.10
# 4                      84.69                       16.51
# ..                       ...                         ...
# 194                       ..                          ..
# 195                       ..                       11.26
# 196                       ..                       15.11
# 197                    57.07                          ..
# 198                       ..                       12.31
#
#     Mean years of schooling Gross national income (GNI) per capita
# 0                     12.57                               68058.62
# 1                     13.38                               59374.73
# 2                     12.53                               55659.68
# 3                     14.13                               46945.95
# 4                     12.04                               60220.80
# ..                      ...                                    ...
# 194                      ..                                     ..
# 195                      ..                               17312.59
# 196                      ..                                     ..
# 197                      ..                                     ..
# 198                      ..                                5408.95
#
# [199 rows x 6 columns]

# %% [markdown]
# Saving previous result:

# %%
hdi=hdi.loc[:,FinalHeaders]

# %%
# you have:
hdi.head()
# Out:
#                   Country Human development index (HDI)   \
# 0                  Norway                           0.95
# 1             Switzerland                           0.95
# 2                 Ireland                           0.94
# 3                 Germany                           0.94
# 4  Hong Kong, China (SAR)                           0.94
#
#   Life expectancy at birth Expected years of schooling  \
# 0                    82.27                       18.06
# 1                    83.63                       16.21
# 2                    82.10                       18.79
# 3                    81.18                       17.10
# 4                    84.69                       16.51
#
#   Mean years of schooling Gross national income (GNI) per capita
# 0                   12.57                               68058.62
# 1                   13.38                               59374.73
# 2                   12.53                               55659.68
# 3                   14.13                               46945.95
# 4                   12.04                               60220.80

# %% [markdown]
# The remaining column names need to improve:

# %%
# replace with '' (empty) the "blanks":
hdi.columns.str.replace("\s","")
# Out:
# Index(['Country', 'Humandevelopmentindex(HDI)', 'Lifeexpectancyatbirth',
#        'Expectedyearsofschooling', 'Meanyearsofschooling',
#        'Grossnationalincome(GNI)percapita'],
#       dtype='object')

# %%
# replace with '' (empty) consecutive word characters in parenthesis:
hdi.columns.str.replace("\(\w+\)","")
# Out:
# Index(['Country', 'Human development index  ', 'Life expectancy at birth',
#        'Expected years of schooling', 'Mean years of schooling',
#        'Gross national income  per capita'],
#       dtype='object')

# %%
#or all combines
hdi.columns.str.replace("\s+|\(\w+\)","")
# Out:
# Index(['Country', 'Humandevelopmentindex', 'Lifeexpectancyatbirth',
#        'Expectedyearsofschooling', 'Meanyearsofschooling',
#        'Grossnationalincomepercapita'],
#       dtype='object')

# %% [markdown]
# Saving result:

# %%
hdi.columns=hdi.columns.str.replace("\s+|\(\w+\)","")

# %%
hdi.head()
# Out:
#                   Country Humandevelopmentindex Lifeexpectancyatbirth  \
# 0                  Norway                  0.95                 82.27
# 1             Switzerland                  0.95                 83.63
# 2                 Ireland                  0.94                 82.10
# 3                 Germany                  0.94                 81.18
# 4  Hong Kong, China (SAR)                  0.94                 84.69
#
#   Expectedyearsofschooling Meanyearsofschooling Grossnationalincomepercapita
# 0                    18.06                12.57                     68058.62
# 1                    16.21                13.38                     59374.73
# 2                    18.79                12.53                     55659.68
# 3                    17.10                14.13                     46945.95
# 4                    16.51                12.04                     60220.80

# %% [markdown]
# #### * Check the cell values

# %% [markdown]
# Find cells where all numeric data is missing, that is, a country with no data:

# %%
# check empty cells from second to last
hdi[hdi.iloc[:,1:].isnull().all(axis=1)] #ALL
# Out:
#                             Country Humandevelopmentindex  \
# 62           HIGH HUMAN DEVELOPMENT                   NaN
# 117        MEDIUM HUMAN DEVELOPMENT                   NaN
# 155           LOW HUMAN DEVELOPMENT                   NaN
# 192  OTHER COUNTRIES OR TERRITORIES                   NaN
#
#     Lifeexpectancyatbirth Expectedyearsofschooling Meanyearsofschooling  \
# 62                    NaN                      NaN                  NaN
# 117                   NaN                      NaN                  NaN
# 155                   NaN                      NaN                  NaN
# 192                   NaN                      NaN                  NaN
#
#     Grossnationalincomepercapita
# 62                           NaN
# 117                          NaN
# 155                          NaN
# 192                          NaN

# %% [markdown]
# These are no countries. They were subtitles for groups of countries.

# %% [markdown]
# You need the opposite to that:

# %%
# the opposite
hdi[hdi.iloc[:,1:].notnull().all(axis=1)]
# Out:
#                     Country Humandevelopmentindex Lifeexpectancyatbirth  \
# 0                    Norway                  0.95                 82.27
# 1               Switzerland                  0.95                 83.63
# 2                   Ireland                  0.94                 82.10
# 3                   Germany                  0.94                 81.18
# 4    Hong Kong, China (SAR)                  0.94                 84.69
# ..                      ...                   ...                   ...
# 194                  Monaco                    ..                    ..
# 195                   Nauru                    ..                    ..
# 196              San Marino                    ..                    ..
# 197                 Somalia                    ..                 57.07
# 198                  Tuvalu                    ..                    ..
#
#     Expectedyearsofschooling Meanyearsofschooling Grossnationalincomepercapita
# 0                      18.06                12.57                     68058.62
# 1                      16.21                13.38                     59374.73
# 2                      18.79                12.53                     55659.68
# 3                      17.10                14.13                     46945.95
# 4                      16.51                12.04                     60220.80
# ..                       ...                  ...                          ...
# 194                       ..                   ..                           ..
# 195                    11.26                   ..                     17312.59
# 196                    15.11                   ..                           ..
# 197                       ..                   ..                           ..
# 198                    12.31                   ..                      5408.95
#
# [195 rows x 6 columns]

# %% [markdown]
# Keepin what you need:

# %%
hdi=hdi[hdi.iloc[:,1:].notnull().all(axis=1)]

# %% [markdown]
# The last code deleted rows, then indexes need to be reset:

# %%
hdi.reset_index(drop=True, inplace=True)

# %% [markdown]
# So far:

# %%
hdi
# Out:
#                     Country Humandevelopmentindex Lifeexpectancyatbirth  \
# 0                    Norway                  0.95                 82.27
# 1               Switzerland                  0.95                 83.63
# 2                   Ireland                  0.94                 82.10
# 3                   Germany                  0.94                 81.18
# 4    Hong Kong, China (SAR)                  0.94                 84.69
# ..                      ...                   ...                   ...
# 190                  Monaco                    ..                    ..
# 191                   Nauru                    ..                    ..
# 192              San Marino                    ..                    ..
# 193                 Somalia                    ..                 57.07
# 194                  Tuvalu                    ..                    ..
#
#     Expectedyearsofschooling Meanyearsofschooling Grossnationalincomepercapita
# 0                      18.06                12.57                     68058.62
# 1                      16.21                13.38                     59374.73
# 2                      18.79                12.53                     55659.68
# 3                      17.10                14.13                     46945.95
# 4                      16.51                12.04                     60220.80
# ..                       ...                  ...                          ...
# 190                       ..                   ..                           ..
# 191                    11.26                   ..                     17312.59
# 192                    15.11                   ..                           ..
# 193                       ..                   ..                           ..
# 194                    12.31                   ..                      5408.95
#
# [195 rows x 6 columns]

# %% [markdown]
# #### * Check the cell values

# %% [markdown]
# Above you see some characters that are not numbers, are they missing values:

# %%
hdi[hdi.iloc[:,1:].isnull().any(axis=1)] #ANY
# Out:
# Empty DataFrame
# Columns: [Country, Humandevelopmentindex, Lifeexpectancyatbirth, Expectedyearsofschooling, Meanyearsofschooling, Grossnationalincomepercapita]
# Index: []

# %% [markdown]
# There are symbols that represent missing values, but they are not recognized so. We need to check what values in those **numeric** columns are not numbers:

# %%
badHDISymbols=[] # list for bad symbols

NumericColNames=hdi.iloc[:,1:].columns # save names of columns with numeric data

for columnName in NumericColNames:# visit every column name
    for cell in hdi[columnName]:# visit every cell for that column
        try:
            float(cell) # try this
        except: # if not possible:            
            if cell not in badHDISymbols:# if cell is not in the list                
                badHDISymbols.append(cell)# add it to the list

# you get:
badHDISymbols
# Out:
# ['..']

# %% [markdown]
# You need to replace that value in the numeric columns:

# %%
import numpy as np

hdi.replace(to_replace=badHDISymbols,value=np.nan,inplace=True)

# %%
# you have:
hdi
# Out:
#                     Country Humandevelopmentindex Lifeexpectancyatbirth  \
# 0                    Norway                  0.95                 82.27
# 1               Switzerland                  0.95                 83.63
# 2                   Ireland                  0.94                 82.10
# 3                   Germany                  0.94                 81.18
# 4    Hong Kong, China (SAR)                  0.94                 84.69
# ..                      ...                   ...                   ...
# 190                  Monaco                   NaN                   NaN
# 191                   Nauru                   NaN                   NaN
# 192              San Marino                   NaN                   NaN
# 193                 Somalia                   NaN                 57.07
# 194                  Tuvalu                   NaN                   NaN
#
#     Expectedyearsofschooling Meanyearsofschooling Grossnationalincomepercapita
# 0                      18.06                12.57                     68058.62
# 1                      16.21                13.38                     59374.73
# 2                      18.79                12.53                     55659.68
# 3                      17.10                14.13                     46945.95
# 4                      16.51                12.04                     60220.80
# ..                       ...                  ...                          ...
# 190                      NaN                  NaN                          NaN
# 191                    11.26                  NaN                     17312.59
# 192                    15.11                  NaN                          NaN
# 193                      NaN                  NaN                          NaN
# 194                    12.31                  NaN                      5408.95
#
# [195 rows x 6 columns]

# %% [markdown]
# When you have numbers in your columns, you can request statistical summaries:

# %%
hdi.describe(include='all')
# Out:
#         Country Humandevelopmentindex Lifeexpectancyatbirth  \
# count       195                   189                   191
# unique      195                    55                   186
# top     Albania                  0.76                 76.70
# freq          1                    10                     2
#
#        Expectedyearsofschooling Meanyearsofschooling  \
# count                       193                  189
# unique                      183                  174
# top                       12.69                 9.67
# freq                          3                    3
#
#        Grossnationalincomepercapita
# count                           191
# unique                          191
# top                         1592.54
# freq                              1

# %% [markdown]
# You are not getting those because they lack format.

# %% [markdown]
# ### -  Formatting

# %% [markdown]
# Check the data types:

# %%
hdi.dtypes
# Out:
# Country                         object
# Humandevelopmentindex           object
# Lifeexpectancyatbirth           object
# Expectedyearsofschooling        object
# Meanyearsofschooling            object
# Grossnationalincomepercapita    object
# dtype: object

# %% [markdown]
# Country can remain as an object (text), but not the rest.

# %% [markdown]
# * **Formatting into numeric type**:

# %%
# as easy as:

hdi[NumericColNames]=hdi.loc[:,NumericColNames].apply(pd.to_numeric)

# %%
#recheck
hdi.dtypes
# Out:
# Country                          object
# Humandevelopmentindex           float64
# Lifeexpectancyatbirth           float64
# Expectedyearsofschooling        float64
# Meanyearsofschooling            float64
# Grossnationalincomepercapita    float64
# dtype: object

# %%
# recheck
hdi.describe(include='all')
# Out:
#         Country  Humandevelopmentindex  Lifeexpectancyatbirth  \
# count       195             189.000000             191.000000
# unique      195                    NaN                    NaN
# top     Albania                    NaN                    NaN
# freq          1                    NaN                    NaN
# mean        NaN               0.713598              72.414660
# std         NaN               0.150813               7.509694
# min         NaN               0.380000              52.810000
# 25%         NaN               0.600000              67.225000
# 50%         NaN               0.730000              73.750000
# 75%         NaN               0.830000              77.700000
# max         NaN               0.950000              84.690000
#
#         Expectedyearsofschooling  Meanyearsofschooling  \
# count                 193.000000            189.000000
# unique                       NaN                   NaN
# top                          NaN                   NaN
# freq                         NaN                   NaN
# mean                   13.212073              8.613228
# std                     2.935116              3.082296
# min                     5.000000              1.590000
# 25%                    11.300000              6.350000
# 50%                    13.070000              9.020000
# 75%                    15.230000             11.290000
# max                    22.100000             14.130000
#
#         Grossnationalincomepercapita
# count                     191.000000
# unique                           NaN
# top                              NaN
# freq                             NaN
# mean                    18368.072461
# std                     19627.352304
# min                       659.730000
# 25%                      4009.435000
# 50%                     11610.910000
# 75%                     26535.420000
# max                    110488.740000

# %% [markdown]
# Some more information:

# %%
hdi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 6 columns):
# Country                         195 non-null object
# Humandevelopmentindex           189 non-null float64
# Lifeexpectancyatbirth           191 non-null float64
# Expectedyearsofschooling        193 non-null float64
# Meanyearsofschooling            189 non-null float64
# Grossnationalincomepercapita    191 non-null float64
# dtypes: float64(5), object(1)
# memory usage: 9.3+ KB

# %% [markdown]
# ## CASE 2: DEMOCRACY INDEX

# %% [markdown]
# Link to use:

# %%
link2 = "https://en.wikipedia.org/wiki/Democracy_Index"

# %%
# import pandas as pd
# maybe you need: pip install beautifulsoup4
#collection
demodex=pd.read_html(link2,
                     header=0,
                     flavor='bs4',
                     attrs={'class': 'wikitable sortable'})[0]

# %% [markdown]
# ## - Cleaning

# %% [markdown]
# * First rows:

# %%
# what's on top?
# names? weird symbols? more links?
demodex.head(10)
# Out:
#   Rank      Country Score Electoral processand pluralism  \
# 0    1       Norway  9.87                          10.00
# 1    2      Iceland  9.58                          10.00
# 2    3       Sweden  9.39                           9.58
# 3    4  New Zealand  9.26                          10.00
# 4    5      Denmark  9.22                          10.00
# 5    6      Ireland  9.15                           9.58
# 6    6       Canada  9.15                           9.58
# 7    8      Finland  9.14                          10.00
# 8    9    Australia  9.09                          10.00
# 9   10  Switzerland  9.03                           9.58
#
#   Functioning ofgovernment Politicalparticipation Politicalculture  \
# 0                     9.64                  10.00            10.00
# 1                     9.29                   8.89            10.00
# 2                     9.64                   8.33            10.00
# 3                     9.29                   8.89             8.13
# 4                     9.29                   8.33             9.38
# 5                     7.86                   8.33            10.00
# 6                     9.64                   7.78             8.75
# 7                     8.93                   8.33             8.75
# 8                     8.93                   7.78             8.75
# 9                     9.29                   7.78             9.38
#
#   Civilliberties      Regimetype      Continent
# 0           9.71  Full democracy         Europe
# 1           9.71  Full democracy         Europe
# 2           9.41  Full democracy         Europe
# 3          10.00  Full democracy        Oceania
# 4           9.12  Full democracy         Europe
# 5          10.00  Full democracy         Europe
# 6          10.00  Full democracy  North America
# 7           9.71  Full democracy         Europe
# 8          10.00  Full democracy        Oceania
# 9           9.12  Full democracy         Europe

# %% [markdown]
# * Last rows:

# %%
# what's at the bottom?
# note? credits? extra info?

demodex.tail(10)
# Out:
#      Rank                           Country  Score  \
# 158   159                      Saudi Arabia   1.93
# 159   159                        Tajikistan   1.93
# 160   161                 Equatorial Guinea   1.92
# 161   162                      Turkmenistan   1.72
# 162   163                              Chad   1.61
# 163   164          Central African Republic   1.52
# 164   165  Democratic Republic of the Congo   1.49
# 165   166                             Syria   1.43
# 166   167                       North Korea   1.08
# 167  Rank                           Country  Score
#
#      Electoral processand pluralism  Functioning ofgovernment  \
# 158                            0.00                      2.86
# 159                            0.08                      0.79
# 160                            0.00                      0.43
# 161                            0.00                      0.79
# 162                            0.00                      0.00
# 163                            2.25                      0.00
# 164                            0.50                      0.71
# 165                            0.00                      0.00
# 166                            0.00                      2.50
# 167  Electoral processand pluralism  Functioning ofgovernment
#
#      Politicalparticipation  Politicalculture  Civilliberties     Regimetype  \
# 158                    2.22              3.13            1.47  Authoritarian
# 159                    1.67              6.25            0.88  Authoritarian
# 160                    3.33              4.38            1.47  Authoritarian
# 161                    2.22              5.00            0.59  Authoritarian
# 162                    1.67              3.75            2.65  Authoritarian
# 163                    1.11              1.88            2.35  Authoritarian
# 164                    2.22              3.13            0.88  Authoritarian
# 165                    2.78              4.38            0.00  Authoritarian
# 166                    1.67              1.25            0.00  Authoritarian
# 167  Politicalparticipation  Politicalculture  Civilliberties     Regimetype
#
#      Continent
# 158       Asia
# 159       Asia
# 160     Africa
# 161       Asia
# 162     Africa
# 163     Africa
# 164     Africa
# 165       Asia
# 166       Asia
# 167  Continent

# %% [markdown]
# From what I saw, I will get rid of the _Score_ and the _Rank_, an also of the last row (it is the repetition of the headers):

# %%
#bye row 167, and two columns
demClean=demodex.drop(index=167,columns=['Rank','Score']).copy()

# %%
demClean
# Out:
#                               Country Electoral processand pluralism  \
# 0                              Norway                          10.00
# 1                             Iceland                          10.00
# 2                              Sweden                           9.58
# 3                         New Zealand                          10.00
# 4                             Denmark                          10.00
# ..                                ...                            ...
# 162                              Chad                           0.00
# 163          Central African Republic                           2.25
# 164  Democratic Republic of the Congo                           0.50
# 165                             Syria                           0.00
# 166                       North Korea                           0.00
#
#     Functioning ofgovernment Politicalparticipation Politicalculture  \
# 0                       9.64                  10.00            10.00
# 1                       9.29                   8.89            10.00
# 2                       9.64                   8.33            10.00
# 3                       9.29                   8.89             8.13
# 4                       9.29                   8.33             9.38
# ..                       ...                    ...              ...
# 162                     0.00                   1.67             3.75
# 163                     0.00                   1.11             1.88
# 164                     0.71                   2.22             3.13
# 165                     0.00                   2.78             4.38
# 166                     2.50                   1.67             1.25
#
#     Civilliberties      Regimetype Continent
# 0             9.71  Full democracy    Europe
# 1             9.71  Full democracy    Europe
# 2             9.41  Full democracy    Europe
# 3            10.00  Full democracy   Oceania
# 4             9.12  Full democracy    Europe
# ..             ...             ...       ...
# 162           2.65   Authoritarian    Africa
# 163           2.35   Authoritarian    Africa
# 164           0.88   Authoritarian    Africa
# 165           0.00   Authoritarian      Asia
# 166           0.00   Authoritarian      Asia
#
# [167 rows x 8 columns]

# %% [markdown]
# As there are few names, we can change to smaller sizes:

# %%
newNames=['pluralism','effectiveness','participation','culture','liberties']

# names from the second and before the last one '[1:-1]':
newMapper={old:new for old,new in zip(demClean.columns[1:-1],newNames)}

demClean.rename(columns=newMapper,inplace=True)

# %%
# this is what we have so far:
demClean.head()
# Out:
#        Country pluralism effectiveness participation culture liberties  \
# 0       Norway     10.00          9.64         10.00   10.00      9.71
# 1      Iceland     10.00          9.29          8.89   10.00      9.71
# 2       Sweden      9.58          9.64          8.33   10.00      9.41
# 3  New Zealand     10.00          9.29          8.89    8.13     10.00
# 4      Denmark     10.00          9.29          8.33    9.38      9.12
#
#        Regimetype Continent
# 0  Full democracy    Europe
# 1  Full democracy    Europe
# 2  Full democracy    Europe
# 3  Full democracy   Oceania
# 4  Full democracy    Europe

# %% [markdown]
# Let me check if there is any rare character in the numbers:

# %%
badDemoSymbols=[] # list for bad symbols

NumericColNames=demClean.iloc[:,1:-2].columns # save names of columns with numeric data

for columnName in NumericColNames:# visit every column name
    for cell in demClean[columnName]:# visit every cell for that column
        try:
            float(cell) # try this
        except: # if not possible:            
            if cell not in badDemoSymbols:# if cell is not in the list                
                badDemoSymbols.append(cell)# add it to the list

# you get:
badDemoSymbols
# Out:
# []

# %% [markdown]
# The last two columns are categories, we should check if the categories are consistent:

# %%
# get unique values in each column:
demClean.iloc[:,-2:].apply(set)
# Out:
# Regimetype    {Hybrid regime, Authoritarian, Flawed democrac...
# Continent     {Asia, Oceania, Africa, Europe, Europe/Asia, S...
# dtype: object

# %%
# easier to see:
demClean.iloc[:,-2:].apply(set).to_list()
# Out:
# [{'Authoritarian', 'Flawed democracy', 'Full democracy', 'Hybrid regime'},
#  {'Africa',
#   'Asia',
#   'Europe',
#   'Europe/Asia',
#   'North America',
#   'Oceania',
#   'South America'}]

# %% [markdown]
# It looks good so far. Let's go to formatting.
#
# ## - Formatting

# %%
# checking data types:
demClean.dtypes
# Out:
# Country          object
# pluralism        object
# effectiveness    object
# participation    object
# culture          object
# liberties        object
# Regimetype       object
# Continent        object
# dtype: object

# %% [markdown]
# * **Formatting into numeric**

# %%
demClean[NumericColNames]=demClean[NumericColNames].apply(pd.to_numeric)

# %% [markdown]
# * **Formatting into nominal**

# %%
demClean.Continent=pd.Categorical(demClean.Continent)

# %% [markdown]
# * **Formatting into ordinal**

# %%
# Check current levels:
pd.unique(demClean.Regimetype).tolist()
# Out:
# ['Full democracy', 'Flawed democracy', 'Hybrid regime', 'Authoritarian']

# %%
#rewrite the levels in order:
correctLevels=['Authoritarian', 'Hybrid regime', 'Flawed democracy','Full democracy']

# %%
#format as ordinal:
demClean.Regimetype=pd.Categorical(demClean.Regimetype,categories=correctLevels,ordered=True)

# %% [markdown]
# The data types have changed:

# %%
#then
demClean.dtypes
# Out:
# Country            object
# pluralism         float64
# effectiveness     float64
# participation     float64
# culture           float64
# liberties         float64
# Regimetype       category
# Continent        category
# dtype: object

# %% [markdown]
# For more detail:

# %%
demClean.Regimetype.cat.ordered
# Out:
# True

# %%
# checking missing values
demClean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 167 entries, 0 to 166
# Data columns (total 8 columns):
# Country          167 non-null object
# pluralism        167 non-null float64
# effectiveness    167 non-null float64
# participation    167 non-null float64
# culture          167 non-null float64
# liberties        167 non-null float64
# Regimetype       167 non-null category
# Continent        167 non-null category
# dtypes: category(2), float64(5), object(1)
# memory usage: 10.0+ KB

# %% [markdown]
# ## Case 3: Integrating and Saving

# %% [markdown]
# This should be an easy step:

# %%
hdi.merge(demClean)
# Out:
#                       Country  Humandevelopmentindex  Lifeexpectancyatbirth  \
# 0                      Norway                   0.95                  82.27
# 1                 Switzerland                   0.95                  83.63
# 2                     Ireland                   0.94                  82.10
# 3                     Germany                   0.94                  81.18
# 4                   Australia                   0.94                  83.28
# ..                        ...                    ...                    ...
# 142                      Mali                   0.43                  58.89
# 143                   Burundi                   0.42                  61.25
# 144                      Chad                   0.40                  53.98
# 145  Central African Republic                   0.38                  52.81
# 146                     Niger                   0.38                  62.02
#
#      Expectedyearsofschooling  Meanyearsofschooling  \
# 0                       18.06                 12.57
# 1                       16.21                 13.38
# 2                       18.79                 12.53
# 3                       17.10                 14.13
# 4                       22.10                 12.68
# ..                        ...                   ...
# 142                      7.60                  2.35
# 143                     11.30                  3.12
# 144                      7.47                  2.41
# 145                      7.57                  4.28
# 146                      6.47                  2.03
#
#      Grossnationalincomepercapita  pluralism  effectiveness  participation  \
# 0                        68058.62      10.00           9.64          10.00
# 1                        59374.73       9.58           9.29           7.78
# 2                        55659.68       9.58           7.86           8.33
# 3                        46945.95       9.58           8.57           8.33
# 4                        44097.02      10.00           8.93           7.78
# ..                            ...        ...            ...            ...
# 142                       1965.39       7.42           3.93           3.89
# 143                        659.73       0.00           0.43           3.89
# 144                       1715.57       0.00           0.00           1.67
# 145                        776.68       2.25           0.00           1.11
# 146                        912.04       5.25           1.14           3.33
#
#      culture  liberties      Regimetype Continent
# 0      10.00       9.71  Full democracy    Europe
# 1       9.38       9.12  Full democracy    Europe
# 2      10.00      10.00  Full democracy    Europe
# 3       7.50       9.41  Full democracy    Europe
# 4       8.75      10.00  Full democracy   Oceania
# ..       ...        ...             ...       ...
# 142     5.63       6.18   Hybrid regime    Africa
# 143     5.00       2.35   Authoritarian    Africa
# 144     3.75       2.65   Authoritarian    Africa
# 145     1.88       2.35   Authoritarian    Africa
# 146     4.38       4.71   Authoritarian    Africa
#
# [147 rows x 13 columns]

# %% [markdown]
# Notice you have lost countries:

# %%
len(demClean),len(hdi)
# Out:
# (167, 195)

# %%
hdi.merge(demClean,how='outer',indicator=True) # see last column
# Out:
#                               Country  Humandevelopmentindex  \
# 0                              Norway                   0.95
# 1                         Switzerland                   0.95
# 2                             Ireland                   0.94
# 3                             Germany                   0.94
# 4              Hong Kong, China (SAR)                   0.94
# ..                                ...                    ...
# 210                              Iran                    NaN
# 211                              Laos                    NaN
# 212  Democratic Republic of the Congo                    NaN
# 213                             Syria                    NaN
# 214                       North Korea                    NaN
#
#      Lifeexpectancyatbirth  Expectedyearsofschooling  Meanyearsofschooling  \
# 0                    82.27                     18.06                 12.57
# 1                    83.63                     16.21                 13.38
# 2                    82.10                     18.79                 12.53
# 3                    81.18                     17.10                 14.13
# 4                    84.69                     16.51                 12.04
# ..                     ...                       ...                   ...
# 210                    NaN                       NaN                   NaN
# 211                    NaN                       NaN                   NaN
# 212                    NaN                       NaN                   NaN
# 213                    NaN                       NaN                   NaN
# 214                    NaN                       NaN                   NaN
#
#      Grossnationalincomepercapita  pluralism  effectiveness  participation  \
# 0                        68058.62      10.00           9.64          10.00
# 1                        59374.73       9.58           9.29           7.78
# 2                        55659.68       9.58           7.86           8.33
# 3                        46945.95       9.58           8.57           8.33
# 4                        60220.80        NaN            NaN            NaN
# ..                            ...        ...            ...            ...
# 210                           NaN       0.00           3.21           4.44
# 211                           NaN       0.83           2.86           1.67
# 212                           NaN       0.50           0.71           2.22
# 213                           NaN       0.00           0.00           2.78
# 214                           NaN       0.00           2.50           1.67
#
#      culture  liberties      Regimetype Continent      _merge
# 0      10.00       9.71  Full democracy    Europe        both
# 1       9.38       9.12  Full democracy    Europe        both
# 2      10.00      10.00  Full democracy    Europe        both
# 3       7.50       9.41  Full democracy    Europe        both
# 4        NaN        NaN             NaN       NaN   left_only
# ..       ...        ...             ...       ...         ...
# 210     3.13       1.47   Authoritarian      Asia  right_only
# 211     5.00       1.47   Authoritarian      Asia  right_only
# 212     3.13       0.88   Authoritarian    Africa  right_only
# 213     4.38       0.00   Authoritarian      Asia  right_only
# 214     1.25       0.00   Authoritarian      Asia  right_only
#
# [215 rows x 14 columns]

# %% [markdown]
# Let me save previous result:

# %%
test=hdi.merge(demClean,how='outer',indicator=True)

# %%
# in hdi only
test.loc[test['_merge']=='left_only',"Country"]
# Out:
# 4                   Hong Kong, China (SAR)
# 17                           Liechtenstein
# 22                     Korea (Republic of)
# 25                                 Czechia
# 35                                 Andorra
# 42                       Brunei Darussalam
# 48                      Russian Federation
# 54                                   Palau
# 55                                Barbados
# 59                                 Bahamas
# 61                              Seychelles
# 64              Iran (Islamic Republic of)
# 72                   Saint Kitts and Nevis
# 73                     Antigua and Barbuda
# 77                                 Grenada
# 89                             Saint Lucia
# 94        Saint Vincent and the Grenadines
# 96      Venezuela (Bolivarian Republic of)
# 97                                Dominica
# 102                                 Belize
# 103                               Maldives
# 104                                  Tonga
# 106                  Moldova (Republic of)
# 111                                  Samoa
# 113       Bolivia (Plurinational State of)
# 116                       Marshall Islands
# 117                               Viet Nam
# 118                    Palestine, State of
# 125                             Cabo Verde
# 132                               Kiribati
# 135       Micronesia (Federated States of)
# 136                  Sao Tome and Principe
# 137                                  Congo
# 138                  Eswatini (Kingdom of)
# 139       Lao People's Democratic Republic
# 140                                Vanuatu
# 152                        Solomon Islands
# 153                   Syrian Arab Republic
# 158          Tanzania (United Republic of)
# 164                          Côte d'Ivoire
# 178     Congo (Democratic Republic of the)
# 185                            South Sudan
# 189    Korea (Democratic People's Rep. of)
# 190                                 Monaco
# 191                                  Nauru
# 192                             San Marino
# 193                                Somalia
# 194                                 Tuvalu
# Name: Country, dtype: object

# %%
# in demClean only
test.loc[test['_merge']=='right_only',"Country"]
# Out:
# 195                    South Korea[n 1]
# 196                          Cape Verde
# 197                              Taiwan
# 198                      Czech Republic
# 199                           Hong Kong
# 200                             Moldova
# 201                             Bolivia
# 202                            Tanzania
# 203                           Palestine
# 204                         Ivory Coast
# 205               Republic of the Congo
# 206                           Venezuela
# 207                             Vietnam
# 208                            Eswatini
# 209                              Russia
# 210                                Iran
# 211                                Laos
# 212    Democratic Republic of the Congo
# 213                               Syria
# 214                         North Korea
# Name: Country, dtype: object

# %%
# you need to change the original

#dictionary of replacements:
replacements={'South Korea[n 1]': 'Korea (Republic of)', 
              'Cape Verde':'Cabo Verde',
              'Czech Republic':'Czechia',
              'Hong Kong':'Hong Kong, China (SAR)',
              'Moldova':'Moldova (Republic of)',
              'Bolivia':'Bolivia (Plurinational State of)',
              'Tanzania':'Tanzania (United Republic of)',
              'Palestine':'Palestine, State of',
              'Ivory Coast':"Côte d'Ivoire",
              'Republic of the Congo':'Congo',
              'Venezuela':'Venezuela (Bolivarian Republic of)',
              'Vietnam':'Viet Nam',
              'Eswatini':'Eswatini (Kingdom of)',              
              'Russia':'Russian Federation',
              'Iran':'Iran (Islamic Republic of)',
              'Laos':"Lao People's Democratic Republic",
              'Democratic Republic of the Congo':'Congo (Democratic Republic of the)',
              'Syria':'Syrian Arab Republic',
              'North Korea': "Korea (Democratic People's Rep. of)" #check ""
             }

# replacing
demClean.Country.replace(replacements,inplace=True)

# %% [markdown]
# The merge should give more rows:

# %%
hdidem=hdi.merge(demClean)
# result:
hdidem
# Out:
#                                  Country  Humandevelopmentindex  \
# 0                                 Norway                   0.95
# 1                            Switzerland                   0.95
# 2                                Ireland                   0.94
# 3                                Germany                   0.94
# 4                 Hong Kong, China (SAR)                   0.94
# ..                                   ...                    ...
# 161                              Burundi                   0.42
# 162                                 Chad                   0.40
# 163             Central African Republic                   0.38
# 164                                Niger                   0.38
# 165  Korea (Democratic People's Rep. of)                    NaN
#
#      Lifeexpectancyatbirth  Expectedyearsofschooling  Meanyearsofschooling  \
# 0                    82.27                     18.06                 12.57
# 1                    83.63                     16.21                 13.38
# 2                    82.10                     18.79                 12.53
# 3                    81.18                     17.10                 14.13
# 4                    84.69                     16.51                 12.04
# ..                     ...                       ...                   ...
# 161                  61.25                     11.30                  3.12
# 162                  53.98                      7.47                  2.41
# 163                  52.81                      7.57                  4.28
# 164                  62.02                      6.47                  2.03
# 165                  72.10                     10.84                   NaN
#
#      Grossnationalincomepercapita  pluralism  effectiveness  participation  \
# 0                        68058.62      10.00           9.64          10.00
# 1                        59374.73       9.58           9.29           7.78
# 2                        55659.68       9.58           7.86           8.33
# 3                        46945.95       9.58           8.57           8.33
# 4                        60220.80       3.08           6.07           5.56
# ..                            ...        ...            ...            ...
# 161                        659.73       0.00           0.43           3.89
# 162                       1715.57       0.00           0.00           1.67
# 163                        776.68       2.25           0.00           1.11
# 164                        912.04       5.25           1.14           3.33
# 165                           NaN       0.00           2.50           1.67
#
#      culture  liberties        Regimetype Continent
# 0      10.00       9.71    Full democracy    Europe
# 1       9.38       9.12    Full democracy    Europe
# 2      10.00      10.00    Full democracy    Europe
# 3       7.50       9.41    Full democracy    Europe
# 4       7.50       8.53  Flawed democracy      Asia
# ..       ...        ...               ...       ...
# 161     5.00       2.35     Authoritarian    Africa
# 162     3.75       2.65     Authoritarian    Africa
# 163     1.88       2.35     Authoritarian    Africa
# 164     4.38       4.71     Authoritarian    Africa
# 165     1.25       0.00     Authoritarian      Asia
#
# [166 rows x 13 columns]

# %% [markdown]
# ____
# ____
#
#
# ### <font color="red">Saving File to Disk</font>

# %% [markdown]
# #### For future use in Python:

# %%
hdidem.to_pickle("hdidemocia.pkl")
# you will need: DF=pd.read_pickle("hdidemocia.pkl")
# or:
# from urllib.request import urlopen
# DF=pd.read_pickle(urlopen("https://...../hdidemocia.pkl"),compression=None)

# %% [markdown]
# #### For future  use in R:

# %%
from rpy2.robjects import pandas2ri
pandas2ri.activate()

from rpy2.robjects.packages import importr

base = importr('base')
base.saveRDS(hdidem,file="hdidem.RDS")

#In R, you call it with: DF = readRDS("hdidem.RDS")
#or, if iyou read from cloud: DF = readRDS(url("https://...../hdidem.RDS")
# Out:
# rpy2.rinterface.NULL
